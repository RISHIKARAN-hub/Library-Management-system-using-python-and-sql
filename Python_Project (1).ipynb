# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Training_data_set.csv')

# %%
df
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad        NaN          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# ...

# %%
df.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count              7534
# seat_count              8511
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
df.drop(columns=['body_type'],inplace=True)

# %%
df['Distance '].fillna(df['Distance '].median(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\2970458654.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Distance '].fillna(df['Distance '].median(),inplace=True)

# %%
df['engine_power'].fillna(df['engine_power'].median(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\3563742412.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['engine_power'].fillna(df['engine_power'].median(),inplace=True)

# %%
df['seat_count'].fillna(df['seat_count'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\1941623346.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['seat_count'].fillna(df['seat_count'].mean(),inplace=True)

# %%
df['door_count'].fillna(df['door_count'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\3819014736.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['door_count'].fillna(df['door_count'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
df['Distance ']=df['Distance '].astype(int)

# %%
df['engine_power']=df['engine_power'].astype(int)

# %%
df['seat_count']=df['seat_count'].astype(int)

# %%
df['door_count']=df['door_count'].astype(int)

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance                 int64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power             int64
# Vroom Audit Rating       int64
# transmission            object
# door_count               int64
# seat_count               int64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Maker']=le.fit_transform(df['Maker'])

# %%
df['model']=le.fit_transform(df['model'])

# %%
df['Location']=le.fit_transform(df['Location'])

# %%
df['Owner Type']=le.fit_transform(df['Owner Type'])

# %%
df['transmission']=le.fit_transform(df['transmission'])

# %%
df['fuel_type']=le.fit_transform(df['fuel_type'])

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance                 int64
# Owner Type               int64
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power             int64
# Vroom Audit Rating       int64
# transmission             int64
# door_count               int64
# seat_count               int64
# fuel_type                int64
# Price                  float64
# dtype: object

# %%
df.boxplot(fontsize=5,figsize=(11,13))
plt.show()

# %%
df1=df.copy()

# %%
q1=df.quantile(0.25)

# %%
q1
# Out:
# Id                      38379.50
# Maker                       1.00
# model                       8.00
# Location                    2.00
# Distance                16507.00
# Owner Type                  0.00
# manufacture_year         2008.00
# Age of car                  5.00
# engine_displacement      1395.00
# engine_power               74.00
# Vroom Audit Rating          5.00
# transmission                0.00
# door_count                  4.00
# seat_count                  4.00
# fuel_type                   0.00
# Price                  505181.25
# Name: 0.25, dtype: float64

# %%
q3=df.quantile(0.75)

# %%
q3
# Out:
# Id                       65136.500
# Maker                        6.000
# model                       16.000
# Location                     8.000
# Distance                133304.000
# Owner Type                   3.000
# manufacture_year          2014.000
# Age of car                  11.000
# engine_displacement       1995.000
# engine_power               125.000
# Vroom Audit Rating           7.000
# transmission                 1.000
# door_count                   4.000
# seat_count                   5.000
# fuel_type                    1.000
# Price                  1477828.875
# Name: 0.75, dtype: float64

# %%
iqr=q3-q1

# %%
iqr
# Out:
# Id                      26757.000
# Maker                       5.000
# model                       8.000
# Location                    6.000
# Distance               116797.000
# Owner Type                  3.000
# manufacture_year            6.000
# Age of car                  6.000
# engine_displacement       600.000
# engine_power               51.000
# Vroom Audit Rating          2.000
# transmission                1.000
# door_count                  0.000
# seat_count                  1.000
# fuel_type                   1.000
# Price                  972647.625
# dtype: float64

# %%
ll=q1-1.5*iqr

# %%
ll
# Out:
# Id                      -1756.0000
# Maker                      -6.5000
# model                      -4.0000
# Location                   -7.0000
# Distance              -158688.5000
# Owner Type                 -4.5000
# manufacture_year         1999.0000
# Age of car                 -4.0000
# engine_displacement       495.0000
# engine_power               -2.5000
# Vroom Audit Rating          2.0000
# transmission               -1.5000
# door_count                  4.0000
# seat_count                  2.5000
# fuel_type                  -1.5000
# Price                 -953790.1875
# dtype: float64

# %%
ul=q3+1.5*iqr

# %%
ul
# Out:
# Id                     1.052720e+05
# Maker                  1.350000e+01
# model                  2.800000e+01
# Location               1.700000e+01
# Distance               3.084995e+05
# Owner Type             7.500000e+00
# manufacture_year       2.023000e+03
# Age of car             2.000000e+01
# engine_displacement    2.895000e+03
# engine_power           2.015000e+02
# Vroom Audit Rating     1.000000e+01
# transmission           2.500000e+00
# door_count             4.000000e+00
# seat_count             6.500000e+00
# fuel_type              2.500000e+00
# Price                  2.936800e+06
# dtype: float64

# %%
df_outliers_removed=df[(df>ll)&(df<ul)]
df_outliers_removed
# Out:
#           Id  Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 0      25001      6      8         0    65520.0           2               NaN
# 1      25002      2      9         0    27750.0           3            2012.0
# 2      25003      1     18         5    46000.0           3            2014.0
# 3      25004      5      6         9    43949.0           3            2011.0
# 4      25005      1     20         6    59524.0           1            2012.0
# ...      ...    ...    ...       ...        ...         ...               ...
# 53510  78511      6      8         4    29334.0           1            2014.0
# 53511  78512      6      8         1   223631.0           1            2009.0
# 53512  78513      1     18        10    25500.0           3            2015.0
# 53513  78514      7      1         6        NaN           3            2011.0
# 53514  78515      1     20         7   142000.0           0            2008.0
#
# ...

# %%
df_outliers_removed.boxplot(fontsize=5,figsize=(8,8))
plt.show()

# %%
del df_outliers_removed['door_count']

# %%
df_outliers_removed.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                595
# Owner Type                0
# manufacture_year       1325
# Age of car             1325
# engine_displacement    5651
# engine_power           1407
# Vroom Audit Rating        0
# transmission              0
# seat_count             1581
# fuel_type                 0
# Price                  1948
# dtype: int64

# %%
df_outliers_removed.dropna(subset=['Distance ','manufacture_year','Age of car','engine_displacement','engine_power','seat_count','Price'],inplace=True)

# %%
df_outliers_removed.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
df2=df_outliers_removed.copy()

# %%
df_stand=pd.DataFrame(ss.fit_transform(df_outliers_removed),columns=df_outliers_removed.columns)

# %%
df_stand
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.731576 -1.213663 -0.286051 -1.584684  -0.668545    1.342231
# 1     -1.731511 -1.649164  1.172524 -0.002763  -0.411411    1.342231
# 2     -1.731447  0.092841 -0.772243  1.262774  -0.440309    1.342231
# 3     -1.731317  0.528342 -0.448115 -0.951916  -0.890244   -1.340158
# 4     -1.731253  0.528342  0.848396 -0.635532   1.490675   -0.446028
# ...         ...       ...       ...       ...        ...         ...
# 44422  1.731876  0.528342 -0.448115 -0.951916   2.642352   -0.446028
# 44423  1.731940  0.963843  1.658716 -0.951916  -1.059529    1.342231
# 44424  1.732005  0.528342 -0.448115 -0.319147  -0.646227   -0.446028
# 44425  1.732070  0.528342 -0.448115 -1.268300   2.091325   -0.446028
# 44426  1.732135 -1.649164  1.172524  1.579158  -0.700246    1.342231
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
df_stand.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df_stand.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'seat_count', 'fuel_type',
#        'Price'],
#       dtype='object')

# %%
X=df_stand[['Id','Maker','model','Location','Distance ','Owner Type','manufacture_year','Age of car','engine_displacement','engine_power','Vroom Audit Rating','transmission','seat_count','fuel_type']]
y=df_stand['Price']

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.score(X,y)
# Out:
# 0.8127040907732422

# %%
y_predicted=pd.DataFrame(model.predict(X),columns=['Y_predicted'])

# %%
y_predicted
# Out:
#        Y_predicted
# 0        -0.203366
# 1         1.535649
# 2         0.319868
# 3         0.860758
# 4         0.127947
# ...            ...
# 44422    -0.960122
# 44423    -0.310531
# 44424     0.260190
# 44425    -0.875491
# 44426     1.723739
#
# [44427 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y,y_predicted)
# Out:
# np.float64(0.1872959092267578)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y,y_predicted)
# Out:
# np.float64(0.32508451846458253)

# %%
df1=pd.read_csv('Test_Data_Set.csv')

# %%
df1.head()
# Out:
#       Id  Maker    model    Location  Distance       Owner Type  \
# 0  11001  skoda  octavia      Mumbai   150000.0           First
# 1  11002  skoda    rapid  Coimbatore    29376.0           Third
# 2  11003  skoda  octavia  Coimbatore    30563.0          Second
# 3  11004   audi       q3       Delhi     8650.0  Fourth & Above
# 4  11005   audi       tt     Chennai     6400.0           Third
#
#    manufacture_year  Age of car  engine_displacement  engine_power body_type  \
# 0              2007          12                 1595          75.0       NaN
# 1              2014           5                 1598          77.0       NaN
# 2              2014           5                 1968         110.0       NaN
# 3              2015           4                 1968         110.0       NaN
# 4              2015           4                 1984         169.0       NaN
#
#    Vroom Audit Rating transmission  door_count  seat_count fuel_type
# ...

# %%
df1.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                128
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power            168
# body_type              5193
# Vroom Audit Rating        0
# transmission              0
# door_count              806
# seat_count              891
# fuel_type                 0
# dtype: int64

# %%
df1.shape
# Out:
# (5615, 16)

# %%
df1.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'body_type', 'Vroom Audit Rating', 'transmission', 'door_count',
#        'seat_count', 'fuel_type'],
#       dtype='object')

# %%
df1.drop(columns=['body_type'],inplace=True)

# %%
df1['Distance '].fillna(df1['Distance '].median(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\2721915470.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Distance '].fillna(df1['Distance '].median(),inplace=True)

# %%
df1['engine_power'].fillna(df1['engine_power'].median(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\2127131134.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['engine_power'].fillna(df1['engine_power'].median(),inplace=True)

# %%
df1['seat_count'].fillna(df1['seat_count'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\2696013374.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['seat_count'].fillna(df1['seat_count'].mean(),inplace=True)

# %%
df1['door_count'].fillna(df1['door_count'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10952\1316297171.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['door_count'].fillna(df1['door_count'].mean(),inplace=True)

# %%
df1.isnull().sum()
# Out:
# Id                       0
# Maker                    0
# model                    0
# Location                 0
# Distance                 0
# Owner Type               0
# manufacture_year         0
# Age of car               0
# engine_displacement      0
# engine_power             0
# Vroom Audit Rating       0
# transmission             0
# door_count             806
# seat_count               0
# fuel_type                0
# dtype: int64

# %%
df1['Distance ']=df1['Distance '].astype(int)

# %%
df1['engine_power']=df1['engine_power'].astype(int)

# %%
df1['seat_count']=df1['seat_count'].astype(int)

# %%
df1['door_count']=df1['door_count'].astype(int)

# %%
df1.dtypes
# Out:
# Id                     int64
# Maker                  int64
# model                  int64
# Location               int64
# Distance               int64
# Owner Type             int64
# manufacture_year       int64
# Age of car             int64
# engine_displacement    int64
# engine_power           int64
# Vroom Audit Rating     int64
# transmission           int64
# door_count             int64
# seat_count             int64
# fuel_type              int64
# dtype: object

# %%
df1['Maker']=le.fit_transform(df1['Maker'])

# %%
df1['model']=le.fit_transform(df1['model'])

# %%
df1['Location']=le.fit_transform(df1['Location'])

# %%
df1['Owner Type']=le.fit_transform(df1['Owner Type'])

# %%
df1['transmission']=le.fit_transform(df1['transmission'])

# %%
df1['fuel_type']=le.fit_transform(df1['fuel_type'])

# %%
q1=df1.quantile(0.25)

# %%
q3=df1.quantile(0.75)

# %%
iqr=q3-q1

# %%
ll=q1-1.5*iqr

# %%
ul=q3+1.5*iqr

# %%
df_outliers_removed=df1[(df1>ll)&(df1<ul)]
df_outliers_removed
# Out:
#          Id  Maker  model  Location  Distance   Owner Type  manufacture_year  \
# 0     11001      6      8         9   150000.0           0            2007.0
# 1     11002      6     14         3    29376.0           3            2014.0
# 2     11003      6      8         3    30563.0           2            2014.0
# 3     11004      0     10         4     8650.0           1            2015.0
# 4     11005      0     17         2     6400.0           3            2015.0
# ...     ...    ...    ...       ...        ...         ...               ...
# 5610  16611      6      8         9   149976.0           0            2011.0
# 5611  16612      6     16         0        NaN           0            2005.0
# 5612  16613      6      8         1   230800.0           2            2005.0
# 5613  16614      5     13         6    63480.0           3            2011.0
# 5614  16615      3      5         6    75000.0           2            2011.0
#
# ...

# %%
df_outliers_removed.boxplot(fontsize=5,figsize=(8,8))
plt.show()

# %%
del df_outliers_removed['door_count']

# %%
df_outliers_removed.isnull().sum()
# Out:
# Id                       0
# Maker                    0
# model                    0
# Location                 0
# Distance                63
# Owner Type               0
# manufacture_year       145
# Age of car             145
# engine_displacement    540
# engine_power           174
# Vroom Audit Rating       0
# transmission             0
# seat_count             161
# fuel_type                0
# dtype: int64

# %%
df_outliers_removed.dropna(subset=['Distance ','manufacture_year','Age of car','engine_displacement','engine_power','seat_count'],inplace=True)

# %%
df_outliers_removed.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
df2=df_outliers_removed.copy()

# %%
df_stand=pd.DataFrame(ss.fit_transform(df_outliers_removed),columns=df_outliers_removed.columns)

# %%
df_stand
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.732712  0.538691 -0.440834  1.266804   1.082766   -1.296291
# 1    -1.732094  0.538691  0.537717 -0.627636  -0.620251    1.352257
# 2    -1.731476  0.538691 -0.440834 -0.627636  -0.603492    0.469408
# 3    -1.730857 -2.057489 -0.114650 -0.311896  -0.912868   -0.413442
# 4    -1.730239 -2.057489  1.026993 -0.943376  -0.944635    1.352257
# ...        ...       ...       ...       ...        ...         ...
# 4759  1.734180  0.538691  0.863901  1.266804   1.256747   -0.413442
# 4760  1.734798 -2.057489 -1.093202  0.319584  -0.844394    0.469408
# 4761  1.736035  0.538691 -0.440834  1.266804   1.082427   -1.296291
# 4762  1.737271  0.538691 -0.440834 -1.259116   2.223532    0.469408
# 4763  1.738508 -0.759399 -0.930110  0.319584   0.023887    0.469408
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.024713    1.024713            -0.134928     -0.494671
# ...

# %%
X=df_stand[['Id','Maker','model','Location','Distance ','Owner Type','manufacture_year','Age of car','engine_displacement','engine_power','Vroom Audit Rating','transmission','seat_count','fuel_type']]

# %%
y_predicted=pd.DataFrame(model.predict(X),columns=['Y_predicted'])

# %%
y_predicted
# Out:
#       Y_predicted
# 0       -1.102888
# 1        0.330387
# 2        0.706794
# 3        1.840065
# 4        2.102914
# ...           ...
# 4759     0.321064
# 4760     1.442017
# 4761    -0.115856
# 4762    -1.247775
# 4763    -0.299111
#
# [4764 rows x 1 columns]

# %%
df3=pd.concat([df_outliers_removed['Id'],y_predicted],axis=1)

# %%
df3
# Out:
#            Id  Y_predicted
# 0     11001.0    -1.102888
# 1     11002.0     0.330387
# 2     11003.0     0.706794
# 3     11004.0     1.840065
# 4     11005.0     2.102914
# ...       ...          ...
# 4745      NaN     0.510306
# 4746      NaN     1.244592
# 4749      NaN    -0.608049
# 4751      NaN     0.319605
# 4762      NaN    -1.247775
#
# [5479 rows x 2 columns]
